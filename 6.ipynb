# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("image.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
width, height = img.shape[:2]

# %%
src_points=np.float32([
    [400, 300],
    [300, 200],
    [500, 250],
    [500, 400]
])

# %%
width=300
height=420
dst_points=np.float32([
    [0,0],
    [width, 0],
    [width,height],
    [0,height]
])

# %%
matrix = cv2.getPerspectiveTransform(src_points, dst_points)
print("Estimated Perspective Transformation Matrix:")
print(matrix)
# Out:
# Estimated Perspective Transformation Matrix:
# [[-3.0e+00  3.0e+00  3.0e+02]
#  [-4.2e+00  4.2e+00  4.2e+02]
#  [-1.0e-02  1.0e-02  1.0e+00]]

# %%
warped=cv2.warpPerspective(img,matrix,(width,height))
warped=cv2.cvtColor(warped,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(953.5), np.float64(1279.5), np.float64(-0.5))

# %%
plt.imshow(warped)
plt.title("Original Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(419.5), np.float64(-0.5))
